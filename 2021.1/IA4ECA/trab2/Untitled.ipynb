# %%
import pandas as pd

# %%
df = pd.read_csv('cv_results.csv', index_col=0)
df = df.drop(['hidden_activation', 'n_epochs'], axis='columns')
df
# Out:
#     hidden_size     lr  n_hidden  Accuracy
# 0             3  0.001         3  0.423551
# 1             3  0.001         4  0.651812
# 2             3  0.001         5  0.431522
# 3             3  0.001         6  0.355435
# 4             3  0.005         3  0.711957
# 5             3  0.005         4  0.762319
# 6             3  0.005         5  0.660145
# 7             3  0.005         6  0.703986
# 8             3  0.010         3  0.778623
# 9             3  0.010         4  0.762319
# 10            3  0.010         5  0.694203
# 11            3  0.010         6  0.686957
# 12            4  0.001         3  0.568116
# 13            4  0.001         4  0.669203
# 14            4  0.001         5  0.550725
# 15            4  0.001         6  0.628261
# 16            4  0.005         3  0.770652
# 17            4  0.005         4  0.728261
# 18            4  0.005         5  0.677899
# 19            4  0.005         6  0.761957
# 20            4  0.010         3  0.745290
# ...

# %%
df.corr()
# Out:
#               hidden_size            lr  n_hidden  Accuracy
# hidden_size  1.000000e+00  1.110543e-17  0.000000  0.165053
# lr           1.110543e-17  1.000000e+00  0.000000  0.420345
# n_hidden     0.000000e+00  0.000000e+00  1.000000 -0.197465
# Accuracy     1.650526e-01  4.203454e-01 -0.197465  1.000000
